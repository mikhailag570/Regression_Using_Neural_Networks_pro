# %% [markdown]
# Дан датасет с результатами проведённых баскетбольных матчей. Необходимо сделать прогноз, сколько всего очков будет набрано обеими командами в матче.
#
# Для каждой игры в датасете есть несколько строк, описывающие хронологию матча. В колонке "info" одинаковые записи соответствуют одному и тому же матчу.

# %% [markdown]
# Необходимо научить нейросеть предсказывать количество набранных очков в матче (fcount).

# %% [markdown]
# Добейтесь средней абсолютной ошибки 17 и менее очков.

# %% [markdown]
# ### Подготовка

# %%
# Загрузка из google облака
import gdown
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l10/basketball.csv', None, quiet=True)

# Библиотека для работы с базами
import pandas as pd
df = pd.read_csv('basketball.csv', encoding= 'cp1251', sep=';', header=0, index_col=0) # Загружаем базу
df.head()
# Out:
#    TOTAL                                               info  Ком. 1  Ком. 2  \
# 0   98,5  4081445 Новая Зеландия. Женщины. WBC. Регулярн...       2     0.0
# 1  100,5  4081445 Новая Зеландия. Женщины. WBC. Регулярн...       2     2.0
# 2   99,5  4081445 Новая Зеландия. Женщины. WBC. Регулярн...       2     2.0
# 3   98,5  4081445 Новая Зеландия. Женщины. WBC. Регулярн...       2     2.0
# 4   95,5  4081445 Новая Зеландия. Женщины. WBC. Регулярн...       2     2.0
#
#    Минута  Общая минута  Секунда  fcount  ftime
# 0       1           1.0       30      81   90.0
# 1       1           1.0       45      81  105.0
# 2       2           2.0        0      81  120.0
# 3       2           2.0       30      81  150.0
# 4       3           3.0        0      81  180.0

# %% [markdown]
# Извлекаем текстовые данные из колонки `info` таблицы, помещаем в переменную `data_text`. Выводим длину списка:

# %%
data_text = df['info'].values #

len(data_text) #
# Out:
# 52450

# %% [markdown]
# Задаем максимальное кол-во слов в словаре, помещаем в переменную все символы, которые хотим вычистить из текста.
#
#  Токенизируем текстовые данные:

# %%
# Импортируем токенайзер
from tensorflow.keras.preprocessing.text import Tokenizer

maxWordsCount = 5000

sim_for_del='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'

tokenizer = Tokenizer (num_words=maxWordsCount,
                       filters=sim_for_del,
                       lower=True,
                       split=' ',
                       oov_token='unknown',
                       char_level=False)

tokenizer.fit_on_texts(data_text)

# %%
# Переводим в Эмбеддинг пространство
Sequences = tokenizer.texts_to_sequences(data_text)

# Вариант  Bag of Words
xBOW_text = tokenizer.sequences_to_matrix(Sequences)

# %% [markdown]
# Преобразуем данные в numpy, подготовим наборы для обучения:

# %%
# Библиотека работы с массивами
import numpy as np

xTrain = np.array(df[['Ком. 1','Ком. 2', 'Минута', 'Секунда','ftime']].astype('int'))
yTrain = np.array(df['fcount'].astype('int'))

# %%
print(xTrain.shape)
print(yTrain.shape)
print(xBOW_text.shape)
# Out:
# (52450, 5)
# (52450,)
# (52450, 5000)

# %%
import matplotlib.pyplot as plt

# Функция по проверке ошибки

def check_MAE_predictl_DubbleInput (model,
                                    x_data,
                                    x_data_text,
                                    y_data_not_scaled,
                                    plot=False):

  mae = 0 # Инициализируем начальное значение ошибки
  y_pred = (model.predict([x_data,x_data_text])).squeeze()

  for n in range (0,len(x_data)):
    mae += abs(y_data_not_scaled[n] - y_pred[n]) # Увеличиваем значение ошибки для текущего элемента
  mae /= len(x_data) # Считаем среднее значение
  print('Среднаяя абслолютная ошибка {:.3f} очков это {:.3f}% от общей выборки в {} игры'.format(mae, (mae/y_data_not_scaled.mean(axis=0))*100,len(x_data)))

  if plot:
     plt.scatter(y_data_not_scaled, y_pred)
     plt.xlabel('Правильные значение')
     plt.ylabel('Предсказания')
     plt.axis('equal')
     plt.xlim(plt.xlim())
     plt.ylim(plt.ylim())
     plt.plot([0, 250], [0, 250])
     plt.show()

# %%
def on_epoch_end_custom(epoch, logs=None):
    check_MAE_predictl_DubbleInput(model_final_scaled,xTrain_scaled,xBOW_text,yTrain,plot=True)

# %%
# Pешение

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, LSTM, concatenate, Flatten
from tensorflow.keras.callbacks import LambdaCallback

# %%
# Шаг 1: Подготовка данных

# Разделение на обучающую и тестовую выборки (80% - 20%)
from sklearn.model_selection import train_test_split

x_train, x_test, xBOW_train, xBOW_test, y_train, y_test = train_test_split(xTrain, xBOW_text, yTrain, test_size=0.2, random_state=42)

# Шаг 2: Определение модели

# Входные слои для числовых и текстовых данных
input_numeric = Input(shape=(x_train.shape[1],))
input_text = Input(shape=(xBOW_train.shape[1],))

# Скрытые слои для числовых данных
x1 = Dense(64, activation='relu')(input_numeric)
x1 = Dense(32, activation='relu')(x1)
x1 = Flatten()(x1)

# Скрытые слои для текстовых данных
x2 = Dense(64, activation='relu')(input_text)
x2 = Dense(32, activation='relu')(x2)

# Объединение обоих входов
combined = concatenate([x1, x2])

# Выходной слой
output = Dense(1)(combined)

# %%
# Создание и компиляция модели
model = Model(inputs=[input_numeric, input_text], outputs=output)
model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
# Шаг 3: Обучение модели
epochs = 100
batch_size = 32

# %%
# Колбэк для проверки MAE после каждой эпохи
on_epoch_end = LambdaCallback(on_epoch_end=lambda epoch, logs: check_MAE_predictl_DubbleInput(model, x_test, xBOW_test, y_test))

model.fit([x_train, xBOW_train], y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, callbacks=[on_epoch_end])
# Out:
# Epoch 1/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Среднаяя абслолютная ошибка 2.312 очков это 1.527% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 33.3313 - val_loss: 2.2851
# Epoch 2/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 2.154 очков это 1.423% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.1514 - val_loss: 2.1676
# Epoch 3/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.213 очков это 0.801% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.7346 - val_loss: 1.2593
# Epoch 4/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.210 очков это 0.799% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 1.6749 - val_loss: 1.2105
# Epoch 5/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.483 очков это 0.979% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.6049 - val_loss: 1.4929
# Epoch 6/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.331 очков это 0.879% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4327 - val_loss: 1.3181
# Epoch 7/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.049 очков это 0.693% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.3406 - val_loss: 1.0464
# Epoch 8/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.089 очков это 0.720% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 1.3546 - val_loss: 1.0981
# Epoch 9/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.237 очков это 0.817% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.3249 - val_loss: 1.2346
# Epoch 10/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.071 очков это 0.708% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2661 - val_loss: 1.0543
# Epoch 11/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.010 очков это 0.667% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.1994 - val_loss: 1.0113
# Epoch 12/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.988 очков это 0.653% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.1708 - val_loss: 1.0030
# Epoch 13/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.713 очков это 1.131% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2113 - val_loss: 1.7008
# Epoch 14/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.368 очков это 0.903% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1479 - val_loss: 1.3766
# Epoch 15/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.238 очков это 0.818% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1741 - val_loss: 1.2764
# Epoch 16/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.700 очков это 1.123% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0643 - val_loss: 1.6811
# Epoch 17/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.001 очков это 0.661% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0526 - val_loss: 1.0191
# Epoch 18/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.886 очков это 0.585% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.9418 - val_loss: 0.8729
# Epoch 19/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 1.060 очков это 0.700% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.9616 - val_loss: 1.0799
# Epoch 20/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.843 очков это 0.557% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.9169 - val_loss: 0.8423
# Epoch 21/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.841 очков это 0.555% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.8942 - val_loss: 0.8427
# Epoch 22/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.831 очков это 0.549% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8947 - val_loss: 0.8250
# Epoch 23/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.814 очков это 0.538% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.8569 - val_loss: 0.8295
# Epoch 24/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.817 очков это 0.540% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8404 - val_loss: 0.8180
# Epoch 25/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.931 очков это 0.615% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.8690 - val_loss: 0.9356
# Epoch 26/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.667 очков это 0.441% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8320 - val_loss: 0.6696
# Epoch 27/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.845 очков это 0.558% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7796 - val_loss: 0.8286
# Epoch 28/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.710 очков это 0.469% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8098 - val_loss: 0.7289
# Epoch 29/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.769 очков это 0.508% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.7629 - val_loss: 0.7602
# Epoch 30/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.664 очков это 0.439% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7723 - val_loss: 0.6623
# Epoch 31/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.670 очков это 0.442% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7312 - val_loss: 0.6810
# Epoch 32/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.749 очков это 0.495% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.6984 - val_loss: 0.7579
# Epoch 33/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.781 очков это 0.516% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.7347 - val_loss: 0.7824
# Epoch 34/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.641 очков это 0.424% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.6824 - val_loss: 0.6495
# Epoch 35/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.611 очков это 0.403% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.6788 - val_loss: 0.6176
# Epoch 36/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.740 очков это 0.489% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.6586 - val_loss: 0.7312
# Epoch 37/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Среднаяя абслолютная ошибка 0.570 очков это 0.377% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.6504 - val_loss: 0.5845
# Epoch 38/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.585 очков это 0.387% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.6299 - val_loss: 0.5918
# Epoch 39/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.614 очков это 0.406% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.6300 - val_loss: 0.6231
# Epoch 40/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.594 очков это 0.392% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.6274 - val_loss: 0.5924
# Epoch 41/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.539 очков это 0.356% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.6158 - val_loss: 0.5445
# Epoch 42/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.546 очков это 0.361% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5840 - val_loss: 0.5476
# Epoch 43/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.606 очков это 0.400% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.5919 - val_loss: 0.6049
# Epoch 44/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.601 очков это 0.397% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5923 - val_loss: 0.6163
# Epoch 45/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.616 очков это 0.407% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5806 - val_loss: 0.6208
# Epoch 46/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.510 очков это 0.337% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.5757 - val_loss: 0.5132
# Epoch 47/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.601 очков это 0.397% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5829 - val_loss: 0.6102
# Epoch 48/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.530 очков это 0.350% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5646 - val_loss: 0.5340
# Epoch 49/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.617 очков это 0.407% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.5594 - val_loss: 0.6215
# Epoch 50/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.561 очков это 0.371% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5781 - val_loss: 0.5602
# Epoch 51/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.745 очков это 0.492% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5643 - val_loss: 0.7559
# Epoch 52/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.580 очков это 0.383% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.5644 - val_loss: 0.5790
# Epoch 53/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.474 очков это 0.313% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5449 - val_loss: 0.4743
# Epoch 54/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.542 очков это 0.358% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5326 - val_loss: 0.5524
# Epoch 55/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.472 очков это 0.312% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.5419 - val_loss: 0.4711
# Epoch 56/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.512 очков это 0.338% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5280 - val_loss: 0.5148
# Epoch 57/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.486 очков это 0.321% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.5294 - val_loss: 0.4904
# Epoch 58/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.479 очков это 0.316% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.5288 - val_loss: 0.4842
# Epoch 59/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.481 очков это 0.318% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5296 - val_loss: 0.4862
# Epoch 60/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.479 очков это 0.316% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.4981 - val_loss: 0.4841
# Epoch 61/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.429 очков это 0.283% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.5181 - val_loss: 0.4351
# Epoch 62/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.487 очков это 0.322% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.5018 - val_loss: 0.4846
# Epoch 63/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.490 очков это 0.324% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5202 - val_loss: 0.4891
# Epoch 64/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.580 очков это 0.383% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4949 - val_loss: 0.5845
# Epoch 65/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.549 очков это 0.363% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5093 - val_loss: 0.5575
# Epoch 66/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.482 очков это 0.318% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5265 - val_loss: 0.4830
# Epoch 67/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.766 очков это 0.506% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4955 - val_loss: 0.7698
# Epoch 68/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.483 очков это 0.319% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5115 - val_loss: 0.4935
# Epoch 69/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.433 очков это 0.286% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4980 - val_loss: 0.4310
# Epoch 70/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.453 очков это 0.299% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4906 - val_loss: 0.4590
# Epoch 71/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.482 очков это 0.318% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4867 - val_loss: 0.4738
# Epoch 72/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.445 очков это 0.294% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4894 - val_loss: 0.4474
# Epoch 73/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.406 очков это 0.268% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4947 - val_loss: 0.4073
# Epoch 74/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.432 очков это 0.285% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.4645 - val_loss: 0.4201
# Epoch 75/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.410 очков это 0.271% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4724 - val_loss: 0.4151
# Epoch 76/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.421 очков это 0.278% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4743 - val_loss: 0.4263
# Epoch 77/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.447 очков это 0.295% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.4645 - val_loss: 0.4529
# Epoch 78/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.413 очков это 0.273% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4651 - val_loss: 0.4235
# Epoch 79/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.405 очков это 0.267% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4655 - val_loss: 0.4109
# Epoch 80/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.484 очков это 0.320% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4631 - val_loss: 0.4847
# Epoch 81/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.494 очков это 0.326% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4736 - val_loss: 0.4901
# Epoch 82/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.441 очков это 0.291% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4604 - val_loss: 0.4396
# Epoch 83/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.514 очков это 0.339% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4435 - val_loss: 0.5170
# Epoch 84/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Среднаяя абслолютная ошибка 0.456 очков это 0.301% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4476 - val_loss: 0.4572
# Epoch 85/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.400 очков это 0.264% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4613 - val_loss: 0.4044
# Epoch 86/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.429 очков это 0.283% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4339 - val_loss: 0.4339
# Epoch 87/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.420 очков это 0.278% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.4537 - val_loss: 0.4214
# Epoch 88/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.388 очков это 0.256% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4419 - val_loss: 0.3888
# Epoch 89/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.505 очков это 0.333% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4459 - val_loss: 0.5003
# Epoch 90/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.453 очков это 0.299% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.4414 - val_loss: 0.4637
# Epoch 91/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.531 очков это 0.351% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.4411 - val_loss: 0.5288
# Epoch 92/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.423 очков это 0.279% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.4321 - val_loss: 0.4234
# Epoch 93/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.377 очков это 0.249% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4442 - val_loss: 0.3759
# Epoch 94/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.369 очков это 0.244% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.4306 - val_loss: 0.3746
# Epoch 95/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.396 очков это 0.262% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.4169 - val_loss: 0.3959
# Epoch 96/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.491 очков это 0.324% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4305 - val_loss: 0.4883
# Epoch 97/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.413 очков это 0.273% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.4292 - val_loss: 0.4119
# Epoch 98/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Среднаяя абслолютная ошибка 0.432 очков это 0.285% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.4281 - val_loss: 0.4443
# Epoch 99/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.483 очков это 0.319% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.4134 - val_loss: 0.4831
# Epoch 100/100
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.412 очков это 0.272% от общей выборки в 10490 игры
# 1049/1049 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4223 - val_loss: 0.4319

# %%
# Финальная оценка на тестовом наборе
check_MAE_predictl_DubbleInput(model, x_test, xBOW_test, y_test)
# Out:
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Среднаяя абслолютная ошибка 0.412 очков это 0.272% от общей выборки в 10490 игры
